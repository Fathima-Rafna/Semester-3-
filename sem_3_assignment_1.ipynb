# %% [markdown]
# <a href="https://colab.research.google.com/github/Fathima-Rafna/Semester-3-/blob/main/sem_3_assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print("Sum =", a + b)
# Out:
# Enter first number: 13
# Enter second number: 16
# Sum = 29

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
print("Product =", a * b)
# Out:
# Enter first number: 21
# Enter second number: 10
# Product = 210

# %%
length = float(input("Enter length: "))
width = float(input("Enter width: "))
area = length * width
print("Area of rectangle =", area)
# Out:
# Enter length: 14
# Enter width: 12
# Area of rectangle = 168.0

# %%
radius = float(input("Enter radius: "))
area = 3.14 * radius * radius
print("Area of circle =", area)
# Out:
# Enter radius: 5
# Area of circle = 78.5

# %%
m1 = int(input("Enter mark 1: "))
m2 = int(input("Enter mark 2: "))
m3 = int(input("Enter mark 3: "))
m4 = int(input("Enter mark 4: "))
m5 = int(input("Enter mark 5: "))

total = m1 + m2 + m3 + m4 + m5
print("Total marks =", total)
# Out:
# Enter mark 1: 10
# Enter mark 2: 15
# Enter mark 3: 25
# Enter mark 4: 5
# Enter mark 5: 15
# Total marks = 70

# %%
def hello_cbs():
    print("Hello CBS")

hello_cbs()
# Out:
# Hello CBS

# %%
def my_name():
    print("Fathima Rafna")
my_name()
# Out:
# Fathima Rafna

# %%
def square_of_10():
    print("Square of 10 =", 10 ** 2)

square_of_10()
# Out:
# Square of 10 = 100

# %%
def sum_20_30():
    print("Sum =", 20 + 30)

sum_20_30()
# Out:
# Sum = 50
